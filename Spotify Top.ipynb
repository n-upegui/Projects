# %% [markdown]
# <a href="https://colab.research.google.com/github/n-upegui/Pojects/blob/main/Spotify%20Top.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Inicio del proyecto de Spotify

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
#Se carga el dataset, se debe agregar el index_col=0 y el encoding='latin-1' para que se pueda leer el dataset con las 
music = pd.read_csv("https://raw.githubusercontent.com/n-upegui/DataSets/main/Spotify%20Top%20Songs/Popular_Spotify_Songs.csv", 
                    index_col=0, encoding='latin-1')
music.head()
# Out:
#                                        artist(s)_name  artist_count  \
# track_name
# Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# LALA                                      Myke Towers             1
# vampire                                Olivia Rodrigo             1
# Cruel Summer                             Taylor Swift             1
# WHERE SHE GOES                              Bad Bunny             1
#
#                                      released_year  released_month  \
# track_name
# Seven (feat. Latto) (Explicit Ver.)           2023               7
# LALA                                          2023               3
# vampire                                       2023               6
# Cruel Summer                                  2019               8
# WHERE SHE GOES                                2023               5
#
#                                      released_day  in_spotify_playlists  \
# track_name
# ...
